# %%
import pandas

# %%
df = pandas.read_csv("list-secrets-scone.csv")
df.columns
# Out:
# Index(['file_name', 'lat_avg', 'lat_stdev', 'lat_max', 'lat_stdevpm',
#        'req_avg', 'req_stdev', 'req_max', 'req_stdevpm', 'tot_requests',
#        'tot_duration', 'read', 'err_connect', 'err_read', 'err_write',
#        'err_timeout', 'req_sec_tot', 'read_tot', 'threads', 'connections',
#        'total_requests', 'total_responses'],
#       dtype='object')

# %%
df1 = pandas.DataFrame(df,columns=['threads','total_requests'])

# %%
print(df1)
# Out:
#      threads  total_requests
# 0        1.0           313.0
# 1        1.0           313.0
# 2        1.0           319.0
# 3        1.0           313.0
# 4        1.0           313.0
# ..       ...             ...
# 895      3.0          1075.0
# 896      3.0          1080.0
# 897      3.0          1080.0
# 898      3.0          1098.0
# 899      3.0          1078.0
#
# [900 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
df1.plot(x ='threads', y='total_requests', kind = 'line')
